# %% [markdown]
# <a href="https://colab.research.google.com/github/fahad15fede/SMIT-ANN_ASSIGNMENTS/blob/main/ANN(Dataset_Bank_Customer_Churn_Dataset).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Bank Customer Churn Prediction - ANN

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Loading Data

# %%
df = pd.read_csv('bank_customer_churn_prediction.csv')

# %%
df.head()
# Out:
#    customer_id  credit_score country  ... active_member  estimated_salary  churn
# 0     15634602           619  France  ...             1         101348.88      1
# 1     15647311           608   Spain  ...             1         112542.58      0
# 2     15619304           502  France  ...             0         113931.57      1
# 3     15701354           699  France  ...             0          93826.63      0
# 4     15737888           850   Spain  ...             1          79084.10      0
#
# [5 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       10000 non-null  int64
#  1   credit_score      10000 non-null  int64
#  2   country           10000 non-null  object
#  3   gender            10000 non-null  object
#  4   age               10000 non-null  int64
#  5   tenure            10000 non-null  int64
#  6   balance           10000 non-null  float64
#  7   products_number   10000 non-null  int64
#  8   credit_card       10000 non-null  int64
#  9   active_member     10000 non-null  int64
#  10  estimated_salary  10000 non-null  float64
#  11  churn             10000 non-null  int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 937.6+ KB

# %% [markdown]
# ## Data Preprocessing

# %%
df.isna().sum()
# Out:
# customer_id         0
# credit_score        0
# country             0
# gender              0
# age                 0
# tenure              0
# balance             0
# products_number     0
# credit_card         0
# active_member       0
# estimated_salary    0
# churn               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#         customer_id  credit_score  ...  estimated_salary         churn
# count  1.000000e+04  10000.000000  ...      10000.000000  10000.000000
# mean   1.569094e+07    650.528800  ...     100090.239881      0.203700
# std    7.193619e+04     96.653299  ...      57510.492818      0.402769
# min    1.556570e+07    350.000000  ...         11.580000      0.000000
# 25%    1.562853e+07    584.000000  ...      51002.110000      0.000000
# 50%    1.569074e+07    652.000000  ...     100193.915000      0.000000
# 75%    1.575323e+07    718.000000  ...     149388.247500      0.000000
# max    1.581569e+07    850.000000  ...     199992.480000      1.000000
#
# [8 rows x 10 columns]

# %%
df.country.unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
df.gender.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df.products_number.unique()
# Out:
# array([1, 3, 2, 4])

# %% [markdown]
# ## Encoding Categorical Features

# %%
df['gender'] = df['gender'].map({
    "Male": 1,
    "Female": 0
})

df = pd.get_dummies(df, columns=['country'], dtype=int)

df.head()
# Out:
#    customer_id  credit_score  ...  country_Germany  country_Spain
# 0     15634602           619  ...                0              0
# 1     15647311           608  ...                0              1
# 2     15619304           502  ...                0              0
# 3     15701354           699  ...                0              0
# 4     15737888           850  ...                0              1
#
# [5 rows x 14 columns]

# %%
df = df.drop('customer_id', axis=1)
df.head()
# Out:
#    credit_score  gender  age  ...  country_France  country_Germany  country_Spain
# 0           619       0   42  ...               1                0              0
# 1           608       0   41  ...               0                0              1
# 2           502       0   42  ...               1                0              0
# 3           699       0   39  ...               1                0              0
# 4           850       0   43  ...               0                0              1
#
# [5 rows x 13 columns]

# %% [markdown]
# ## Defining Input Features (X) and Target Variable (y)

# %%
X = df.drop('churn', axis=1)
y = df['churn']

# %% [markdown]
# ## Applying Feature Scaling

# %%
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)
X_scaled = X_scaled.astype('float32')

# %% [markdown]
# ## Train-Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y,
    test_size=0.2,
    random_state=42
)

# %% [markdown]
# ## Building ANN (Artificial Neural Network) architecture

# %%
X_train.shape[1]
# Out:
# 12

# %%
model = Sequential()

model.add(Input(shape=(X_train.shape[1],)))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.3))
model.add(Dense(32, activation="relu"))
model.add(Dropout(0.3))
model.add(Dense(16, activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(1, activation="sigmoid"))

# %% [markdown]
# ## Compiling and Training Model

# %%
model.compile(
    optimizer=Adam(learning_rate=0.01),
    loss="binary_crossentropy",
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential_25"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_77 (Dense)                │ (None, 64)             │           832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_78 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_79 (Dense)                │ (None, 16)             │           528 │
# ...

# %%
early_stop = EarlyStopping(
    monitor="val_loss",
    verbose=1,
    patience=15,
    restore_best_weights=True
)

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=100,
    batch_size=32,
    callbacks=early_stop
)
# Out:
# Epoch 1/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8040 - loss: 0.4482 - val_accuracy: 0.8485 - val_loss: 0.3635
# Epoch 2/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8342 - loss: 0.4021 - val_accuracy: 0.8520 - val_loss: 0.3577
# Epoch 3/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8413 - loss: 0.3857 - val_accuracy: 0.8325 - val_loss: 0.3685
# Epoch 4/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8428 - loss: 0.3776 - val_accuracy: 0.8440 - val_loss: 0.3567
# Epoch 5/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8495 - loss: 0.3707 - val_accuracy: 0.8470 - val_loss: 0.3530
# Epoch 6/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8511 - loss: 0.3687 - val_accuracy: 0.8600 - val_loss: 0.3493
# Epoch 7/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8487 - loss: 0.3668 - val_accuracy: 0.8500 - val_loss: 0.3531
# Epoch 8/100
# ...

# %%
plt.plot(history.history['loss'], label="training_loss")
plt.plot(history.history['val_loss'], label="validation_loss")
plt.legend()
plt.show()

# %%
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5).astype(int)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step

# %% [markdown]
# ## Evaluating Model Performance

# %%
train_loss, train_accuracy = model.evaluate(X_train, y_train, verbose=0)
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)

print(f'Training Loss: {train_loss:.4f}, Training Accuracy: {train_accuracy:.4f}')
print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}')
# Out:
# Training Loss: 0.3298, Training Accuracy: 0.8680
# Test Loss: 0.3364, Test Accuracy: 0.8660

# %% [markdown]
# ## Classification Report

# %%
from sklearn.metrics import classification_report

# Generate predictions for the test set
y_pred_test = (model.predict(X_test) > 0.5).astype("int32")

# Print classification report
print("Classification Report for Test Set:")
print(classification_report(y_test, y_pred_test))
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Classification Report for Test Set:
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92      1607
#            1       0.82      0.40      0.54       393
#
#     accuracy                           0.87      2000
#    macro avg       0.85      0.69      0.73      2000
# weighted avg       0.86      0.87      0.85      2000
